# %%
# !git clone https://github.com/sakunithilakarathne/Capacitated-Vehicle-Routing.git
# Out:
# Cloning into 'Capacitated-Vehicle-Routing'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 69 (delta 34), reused 50 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 15.87 KiB | 15.87 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# %cd Capacitated-Vehicle-Routing/
# Out:
# /content/Capacitated-Vehicle-Routing

# %%
# !git checkout develop
# Out:
# Branch 'develop' set up to track remote branch 'develop' from 'origin'.
# Switched to a new branch 'develop'

# %%
# !git branch
# Out:
# * develop
#   main

# %%
# setting path
import sys
sys.path.append('/content/Capacitated-Vehicle-Routing')

# %%
# !pip install pulp
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 57.2 MB/s eta 0:00:00
# ...

# %%
# !pip install wandb tqdm matplotlib numpy

# %%
import wandb
# Authenticate W&B
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: scsthilakarathne (scsthilakarathne-nibm) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# PLOTTING ROUTES

# %%
from src.plot_routes import plot_ga_routes, plot_mip_routes

# %%
plot_ga_routes()
# Out:
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/Capacitated-Vehicle-Routing/wandb/run-20251017_070634-p2q4b7fw</code>
# Syncing run <strong><a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing/runs/p2q4b7fw' target="_blank">cerulean-snowflake-16</a></strong> to <a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing' target="_blank">https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing</a>
#  View run at <a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing/runs/p2q4b7fw' target="_blank">https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing/runs/p2q4b7fw</a>
# wandb:   3 of 3 files downloaded.
# wandb:   4 of 4 files downloaded.
# ...

# %%
plot_mip_routes()
# Out:
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/Capacitated-Vehicle-Routing/wandb/run-20251017_070652-n81rxga5</code>
# Syncing run <strong><a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing/runs/n81rxga5' target="_blank">distinctive-snow-17</a></strong> to <a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing' target="_blank">https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing</a>
#  View run at <a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing/runs/n81rxga5' target="_blank">https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing/runs/n81rxga5</a>
# wandb:   1 of 1 files downloaded.
# wandb:   4 of 4 files downloaded.
# ...

# %% [markdown]
# TRAINING MIP

# %%
from src.models.mixed_integer_programmin import run_cvrp_mip

# %%
run_cvrp_mip()
# Out:
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/Capacitated-Vehicle-Routing/wandb/run-20251017_064712-sz4y5r2l</code>
# Syncing run <strong><a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing/runs/sz4y5r2l' target="_blank">MIP_CVRP_Run</a></strong> to <a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing' target="_blank">https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing</a>
#  View run at <a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing/runs/sz4y5r2l' target="_blank">https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing/runs/sz4y5r2l</a>
# wandb:   4 of 4 files downloaded.
# ...

# %% [markdown]
# HP TUNING GA

# %%
from src.hyperparamter_tuning.ga_tuning import run_ga_with_config

# %%
run_ga_with_config()
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Ignoring project 'Capacitated-Vehicle-Routing' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/Capacitated-Vehicle-Routing/wandb/run-20251017_045502-0vahrgqs</code>
# ...

# %% [markdown]
# TRAIN GA

# %%
from src.models.genetic_algorithm import run_genetic_algorithm

# %%
run_genetic_algorithm()
# Out:
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/Capacitated-Vehicle-Routing/wandb/run-20251017_043723-e4s0eew4</code>
# Syncing run <strong><a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing/runs/e4s0eew4' target="_blank">GA_CVRP_Run</a></strong> to <a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing' target="_blank">https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing</a>
#  View run at <a href='https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing/runs/e4s0eew4' target="_blank">https://wandb.ai/scsthilakarathne-nibm/Capacitated-Vehicle-Routing/runs/e4s0eew4</a>
# wandb:   4 of 4 files downloaded.
# ...
